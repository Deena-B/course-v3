# %% [markdown]
# # Move .png files into labeled folders

# %%
from fastai import *
from fastai.vision import *

# %%
# navigate to correct folder
# %cd ~/course-v3/data_GPU/breast_histo_PTM/before/
# Out:
# /home/ubuntu/course-v3/data_GPU/breast_histo_PTM/before

# %%
ls
# Out:
# 10253/  12242/  12895/  13459/  15472/  8916/  9225/
# 10254/  12626/  12896/  13460/  15473/  8917/  9226/
# 10255/  12748/  12897/  13461/  15510/  8918/  9227/
# 10256/  12749/  12898/  13462/  15512/  8950/  9228/
# 10257/  12750/  12900/  13591/  15513/  8951/  9250/
# 10258/  12751/  12901/  13613/  15514/  8955/  9254/
# 10259/  12752/  12905/  13616/  15515/  8956/  9255/
# 10260/  12810/  12906/  13617/  15516/  8957/  9256/
# 10261/  12811/  12907/  13666/  15632/  8959/  9257/
# 10262/  12817/  12908/  13687/  15633/  8974/  9258/
# 10264/  12818/  12909/  13688/  15634/  8975/  9259/
# 10268/  12819/  12910/  13689/  15839/  8980/  9260/
# 10269/  12820/  12911/  13691/  15840/  8984/  9261/
# 10272/  12821/  12929/  13692/  15902/  9022/  9262/
# 10273/  12822/  12930/  13693/  15903/  9023/  9265/
# 10274/  12823/  12931/  13694/  16014/  9029/  9266/
# 10275/  12824/  12932/  13916/  16085/  9035/  9267/
# 10276/  12826/  12933/  14078/  16165/  9036/  9290/
# ...

# %%
cd 10253
# Out:
# /home/ubuntu/course-v3/data_GPU/breast_histo_PTM/before/10253

# %%
ls
# Out:
# 0/  1/

# %%
cd 1
# Out:
# /home/ubuntu/course-v3/data_GPU/breast_histo_PTM/before/10253/1

# %%
ls
# Out:
# 10253_idx5_x501_y351_class1.png  10253_idx5_x751_y201_class1.png
# 10253_idx5_x501_y401_class1.png  10253_idx5_x751_y251_class1.png
# 10253_idx5_x551_y301_class1.png  10253_idx5_x751_y301_class1.png
# 10253_idx5_x551_y351_class1.png  10253_idx5_x751_y351_class1.png
# 10253_idx5_x551_y401_class1.png  10253_idx5_x751_y401_class1.png
# 10253_idx5_x551_y451_class1.png  10253_idx5_x751_y451_class1.png
# 10253_idx5_x551_y651_class1.png  10253_idx5_x751_y501_class1.png
# 10253_idx5_x551_y701_class1.png  10253_idx5_x751_y551_class1.png
# 10253_idx5_x601_y251_class1.png  10253_idx5_x751_y601_class1.png
# 10253_idx5_x601_y301_class1.png  10253_idx5_x751_y651_class1.png
# 10253_idx5_x601_y351_class1.png  10253_idx5_x751_y701_class1.png
# 10253_idx5_x601_y401_class1.png  10253_idx5_x751_y751_class1.png
# 10253_idx5_x601_y601_class1.png  10253_idx5_x801_y251_class1.png
# 10253_idx5_x601_y651_class1.png  10253_idx5_x801_y301_class1.png
# ...

# %%
cd /home/ubuntu/course-v3/data_GPU/breast_histo_PTM/before
# Out:
# /home/ubuntu/course-v3/data_GPU/breast_histo_PTM/before

# %%
# open an image to make sure it is visible
# do this by navigating in JN's folder structure & clicking on the image

# %%
paths = list(Path('.').rglob('*.png')); paths
# Out:
# [PosixPath('13023/0/13023_idx5_x1501_y1001_class0.png'),
#  PosixPath('13023/0/13023_idx5_x301_y751_class0.png'),
#  PosixPath('13023/0/13023_idx5_x1551_y851_class0.png'),
#  PosixPath('13023/0/13023_idx5_x401_y1001_class0.png'),
#  PosixPath('13023/0/13023_idx5_x501_y1001_class0.png'),
#  PosixPath('13023/0/13023_idx5_x151_y1051_class0.png'),
#  PosixPath('13023/0/13023_idx5_x651_y901_class0.png'),
#  PosixPath('13023/0/13023_idx5_x751_y851_class0.png'),
#  PosixPath('13023/0/13023_idx5_x151_y951_class0.png'),
#  PosixPath('13023/0/13023_idx5_x1051_y1001_class0.png'),
#  PosixPath('13023/0/13023_idx5_x1601_y901_class0.png'),
#  PosixPath('13023/0/13023_idx5_x301_y901_class0.png'),
#  PosixPath('13023/0/13023_idx5_x1251_y551_class0.png'),
#  PosixPath('13023/0/13023_idx5_x1451_y1001_class0.png'),
#  PosixPath('13023/0/13023_idx5_x251_y1051_class0.png'),
#  PosixPath('13023/0/13023_idx5_x901_y851_class0.png'),
#  PosixPath('13023/0/13023_idx5_x1251_y401_class0.png'),
# ...

# %%
fname = paths[0].name; fname
# Out:
# '13023_idx5_x1501_y1001_class0.png'

# %%
fnames = []

# %%
for path in paths:
    fname = path.name
    fnames.append(fname)

# %%
fnames
# Out:
# ['13023_idx5_x1501_y1001_class0.png',
#  '13023_idx5_x301_y751_class0.png',
#  '13023_idx5_x1551_y851_class0.png',
#  '13023_idx5_x401_y1001_class0.png',
#  '13023_idx5_x501_y1001_class0.png',
#  '13023_idx5_x151_y1051_class0.png',
#  '13023_idx5_x651_y901_class0.png',
#  '13023_idx5_x751_y851_class0.png',
#  '13023_idx5_x151_y951_class0.png',
#  '13023_idx5_x1051_y1001_class0.png',
#  '13023_idx5_x1601_y901_class0.png',
#  '13023_idx5_x301_y901_class0.png',
#  '13023_idx5_x1251_y551_class0.png',
#  '13023_idx5_x1451_y1001_class0.png',
#  '13023_idx5_x251_y1051_class0.png',
#  '13023_idx5_x901_y851_class0.png',
#  '13023_idx5_x1251_y401_class0.png',
#  '13023_idx5_x201_y751_class0.png',
#  '13023_idx5_x1401_y451_class0.png',
#  '13023_idx5_x351_y951_class0.png',
#  '13023_idx5_x201_y1101_class0.png',
#  '13023_idx5_x251_y951_class0.png',
#  '13023_idx5_x1401_y1001_class0.png',
#  '13023_idx5_x701_y351_class0.png',
#  '13023_idx5_x801_y401_class0.png',
# ...

# %%
 '13023_idx5_x801_y401_class0.png',

# %%
pat = r"[c]

# %%
doc(ImageDataBunch.from_name_re)

# %%
ImageDataBunch.from_name_re(paths, fnames, )
